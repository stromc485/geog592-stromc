# %% [markdown]
# <div style="padding: 30px; display: grid; grid-template-columns: 66% 34%; width: 100%; background: #13294B">
#
#   <div style="padding: 20px;">
#
#   <div class="geog592-title" style= "color: #81a4d9; font-size: 42px; font-weight: 800; letter-spacing: 2px;font-family: Impact, Haettenschweiler, Arial Black; margin: 0; line-height: 1;">
#       GEOG 592
#     </div>
#
#   <div class="geog592-subtitle" style= "color: #81a4d9; font-family: Arial, Helvetica, sans-serif; font-size: 21px; font-weight: 600; margin-top: 10px;">
#       GIS Programming
#     </div>
#
#   <div class="geog592-module" style= "color: #81a4d9; font-family: Arial, Helvetica, sans-serif; font-size: 16px; margin-top: 6px;">
#       Module 1 — Day 2: Python Fundamentals (functions)
#     </div>
#     </div>
#
# <div class="geog592-header" style= "background: #13294B;">
#
#   <img src="592_avatar_lr.png" alt="GEOG 592 icon">
#
#   <div>
# </div>

# %% [markdown]
# ## 1. Why use functions?
#
# Instead of repeating the same logic several times, we can write it once and reuse it.  This makes code easier to read and debug.
#
# For example, converting from miles to kilometers
#
# ```python
# distance1_km = distance1_miles * 1.60934
# distance2_km = distance2_miles * 1.60934
# distance3_km = distance3_miles * 1.60934
# ```
#
# can be done in one reusable function.

# %% [markdown]
# ## 2. Your first function
#
# A function begins with `def`.
#
# Look at the example below.  Notice that a declaration requires
# - the function name
# - parentheses `()`
# - and a colon `:`
#
# The body of the function is separated from the rest of your code using *indentation.*

# %%
def say_hello():
    print("Welcome to GEOG 592")

# %% [markdown]
# Defining the function does **not** run it.
#
# To run the function, we **call** it:

# %%
say_hello()
# Out:
# Welcome to GEOG 592

# %% [markdown]
# ### Anatomy of the function
#
# ```python
# def say_hello():
#     print("Welcome to GEOG 592")
# ```
#
# - `def` tells Python that we are defining a function.
# - `say_hello` is the function name.
# - `()` contains parameters, if the function needs any.
# - `:` marks the start of the function block.
# - the indented code belongs to the function.

# %% [markdown]
# ## 3. Parameters and arguments
#
# A **parameter** is a name listed (inside the parentheses) in the function declaration. It behaves like a variable in the function body.

# %%
def greet_student(name):
    print(f"Welcome, {name}")

# %% [markdown]
#  Arguments are the values or other variables provided to the function by putting them in parentheses when the function is called.
#
#  The corresponding parameter in the function body will be initially set the value of the argument.

# %%
greet_student("Maria")
greet_student("Carlos")
# Out:
# Welcome, Maria
# Welcome, Carlos

# %% [markdown]
# In:
#
# ```python
# def greet_student(name):
# ```
#
# `name` is the **parameter**.
#
# In:
#
# ```python
# greet_student("Maria")
# ```
#
# `"Maria"` is the **argument**.

# %% [markdown]
# ## 4. Another example function

# %%
def miles_to_km(miles):
    kilometers = miles * 1.60934
    print(kilometers)

# %%
miles_to_km(10)
miles_to_km(25)
# Out:
# 16.0934
# 40.2335

# %% [markdown]
# This works, but the function only displays the answer.
#
# What if we want to save the result and use it later?

# %% [markdown]
# ## 5. `return`
#
# `return` sends a value back to the place where the function was called.

# %%
def miles_to_km(miles):
    kilometers = miles * 1.60934
    return kilometers
print(miles_to_km(1))
# Out:
# 1.60934

# %%
miles_to_km(1)

# %%
distance = miles_to_km(10) ## here, the parameter miles, of the function miles_to_km, is given the argument 10, 
# The function returns the argument converted to kilometers. 
# The returned value is assigned to the variable distance.  

print(distance)
# Out:
# 16.0934

# %% [markdown]
# ### `print()` versus `return`
#
# `print()` displays a result.
#
# `return` gives the result back so another part of the program can use it.

# %%
distance = miles_to_km(10)

double_distance = distance * 2

print(double_distance)
# Out:
# 32.1868

# %% [markdown]
# ## `return` also ends the function
#
# When Python reaches a `return` statement, the function stops immediately.
#
# Any code inside the function that comes after `return` will not run.
#
# This is similar to how `break` stops a loop, but there is an important difference:
#
# - `return` stops the entire function and can send a value back. It only works inside functions.
# - `break` stops a loop.
#
# For example:

# %%
def check_value(value):

    if value < 0:
        return "Invalid value"

    print("The value is >= 0")

    return "Valid value"

### run the function with different values to see how it behaves

# %%
check_value(1)
# Out:
# The value is >= 0
# 'Valid value'

# %%
for number in range(10):
    if number == 4:
        break
    print(number)

# %% [markdown]
# ## 6. More than one parameter
# Functions can have as many parameters as you wish. However you should consider that the more parameters you use, the more complicated and difficult it becomes to remember how to call the function.

# %%
def rectangle_area(width, height):
    area = width * height
    return area
print(rectangle_area(5, 10))
# Out:
# 50

# %%
area = rectangle_area(20, 10)

print(area)
# Out:
# 200

# %% [markdown]
# In:
#
# ```python
# rectangle_area(20, 10)
# ```
#
# Python matches the arguments by position:
#
# ```text
# width  = 20
# height = 10
# ```

# %% [markdown]
# ## 7. Functions can make decisions

# %%
def classify_distance(distance):

    if distance < 1000:
        return "near"
    else:
        return "far"

# %%
print(classify_distance(450))
print(classify_distance(2200))
# Out:
# near
# far

# %% [markdown]
# ## 8. Returning `True` or `False`
#
# Functions can answer yes/no questions with Boolean values.

# %%
def is_positive(value):

    if value > 0:
        return True
    else:
        return False

# %%
print(is_positive(25))
print(is_positive(-4))
# Out:
# True
# False

# %% [markdown]
# ## 9. Side quest: error handling
#
# Later, when we work with CSV files, all values will initially be imported as strings.  We may want to know if the *value can successfully be converted to a number.*
#
# One way to do this would be to check every character in the string and make sure each of them is numeric in it.  But you would have to also allow '-' and '.' to be characters to include negative numbers and floats. And there could only be one negative sign and one period, and the negative sign would need to be at the beginning of the string...
#
# Python already has functions to convert strings to numbers, and will print an error message when you try to convert an invalid string:

# %%
# Example of Python's built-in error checking

#this is fine
good_float=float('123.4')
print(good_float)
#this causes an error
bad_float = float('--123.4')
print('My only dream is to be printed when this cell executes.') #too bad...
# Out:
# 123.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 7
#       3 #this is fine
#       4 good_float=float('123.4')
#       5 print(good_float)
#       6 #this causes an error
# ----> 7 bad_float = float('--123.4')
#       8 print('My only dream is to be printed when this cell executes.') #too bad...
#
# ValueError: could not convert string to float: '--123.4'

# %% [markdown]
# The code above caused a `ValueError` error.
#
# **Error handling** allows you to use Python's internal error checks without ending your code's execution.
#
# You instruct Python to `try` a block of (indented!) code.  If it causes an error matching the type listed in the `except` statement, it will execute that code.

# %%
#this is fine
string_but_not_float = '--123.4'
try: 
    bad_float = float(string_but_not_float)
except ValueError:
    print(f'Oops, someone entered {string_but_not_float} in the CSV.') #the program never gets here
print('Life goes on.')
# Out:
# Oops, someone entered --123.4 in the CSV.
# Life goes on.

# %% [markdown]
# An unqualified `except:` will catch *any* error.
#
# That's not always a good thing!
#
# If you want Python to help you find errors in your code, *you should specifically list only the errors you expect* in the except statement.
#
# For example, the following code runs, and prints unhelpful information for the programmer.
#
# > **Lesson:** Don't handle errors you don't recognize.

# %%
good_float_string = '123.4'
try: 
    bad_float = float(good_float_string) * undeclared_variable
except ValueError : #a better programmer would write 'except ValueError:'
    print(f'Oops, someone entered {string_but_not_float} in the CSV.') #the program never gets here
print('Life goes on.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       1 good_float_string = '123.4'
#       2 try:
#       3     bad_float = float(good_float_string) * undeclared_variable
# ----> 4 except ValueError : #a better programmer would write 'except ValueError:'
#       5     print(f'Oops, someone entered {string_but_not_float} in the CSV.') #the program never gets here
#       6 print('Life goes on.')
#
# NameError: name 'undeclared_variable' is not defined

# %% [markdown]
# now change the `except:` statement in the code above to anticipate a ValueError, and see what happens.

# %% [markdown]
# ## 10. Using error handling in functions
#
# Here's a function that uses error handling to *test* whether or not a value can be converted to a float.

# %%
def can_be_float(value):

    try:
        float(value)
        return True

    except ValueError:
        return False

# %%
print(can_be_float("24.5"))
print(can_be_float("30"))
print(can_be_float("hello"))
# Out:
# True
# True
# False

# %% [markdown]
# You do not need to master `try` / `except` today, but you should understand what the function `can_be_float(value)` does.

# %% [markdown]
# ## 10. Functions inside loops

# %%
values = ["23.4", "18.7", "error", "31.2"]

for value in values:

    if not can_be_float(value):
        print("Suspicious value:", value)
# Out:
# Suspicious value: error

# %% [markdown]
# ### Practice loops (again!).
# Edit the code below so that it prints the index of the array where there is a suspicious value.

# %%
values = ["23.4", "18.7", "error", "31.2"]

for value in values:
    if not can_be_float(value):
        print("Suspicious value:", value, 'at some index')
# Out:
# Suspicious value: error at some index

# %% [markdown]
# ## Practice 1 — Write and call a function
#
# Create:
#
# ```python
# show_course()
# ```
#
# that prints:
#
# ```text
# GEOG 592
# ```
#
# Then call the function.

# %%
# Your code here
def show_course(course_name):
    print(course_name)

show_course("GEOG 592")
# Out:
# GEOG 592

# %% [markdown]
# ## Practice 2 — Add a parameter
#
# Create:
#
# ```python
# show_county(county)
# ```
#
# so that:
#
# ```python
# show_county("Orange")
# ```
#
# prints:
#
# ```text
# County: Orange
# ```

# %%
# Your code here
def show_county(county):
    print(f"County: {county}")

show_county("Orange")
# Out:
# County: Orange

# %% [markdown]
# ## Practice 3 — Return a value
#
# Create:
#
# ```python
# meters_to_km(meters)
# ```
#
# The function should divide meters by `1000` and **return** the result.
#
# Test it with:
#
# ```python
# meters_to_km(5000)
# ```

# %%
# Your code here
def meters_to_km(meters):
    kilometers = meters / 1000
    return kilometers

meters_to_km(5000)
# Out:
# 5.0

# %% [markdown]
# ## Practice 4 — Two parameters
#
# Write:
#
# ```python
# population_density(population, area)
# ```
#
# that returns:
#
# ```text
# population / area
# ```

# %%
# Your code here
def population_density(population, area):
	density = population/area 
	return density 

population_density(100, 2)
# Out:
# 50.0

# %% [markdown]
# ## Practice 5 — Function with a condition
#
# Write:
#
# ```python
# is_valid_percentage(value)
# ```
#
# The function should return:
#
# - `True` if `value` is between 0 and 100;
# - `False` otherwise.

# %%
# Your code here

def is_valid_percentage(value):
	if value > 0 and value < 100:
		return True
	else:
		return False

is_valid_percentage(101)
# Out:
# False

# %% [markdown]
# ## Practice 6 — Use the function in a loop
#
# Use `is_valid_percentage()` to check:
#
# ```python
# values = [24, 56, -2, 101, 37]
# ```
#
# Print only the suspicious values.

# %%
suspicious_values = []
values = [24, 56, -2, 101, 37]

for value in values:
    if value < 0 or value > 100:
        suspicious_values.append(value)

print(suspicious_values)

# Your code here
# Out:
# [-2, 101]

# %% [markdown]
# # Check Your Understanding
#
# ### 1. What is the difference between defining and calling a function?
#
# ### 2. What is the parameter here?
#
# ```python
# def miles_to_km(miles):
#     return miles * 1.60934
# ```
#
# ### 3. What is the argument here?
#
# ```python
# miles_to_km(10)
# ```
#
# ### 4. Why is `return` more useful than `print()` when another part of the program needs the result?
#
# ### 5. What does this return?
#
# ```python
# def is_large(value):
#     if value > 100:
#         return True
#     else:
#         return False
# ```
#
# when called with:
#
# ```python
# is_large(75)
# ```

# %% [markdown]
# # Key ideas
#
# A function often follows this pattern:
#
# ```python
# def function_name(parameter):
#     # code
#     return result
# ```
#
# Think of it as:
#
# ```text
# INPUT
#   ↓
# FUNCTION
#   ↓
# OUTPUT
# ```
#
# Functions help us:
#
# - avoid repeating code;
# - give a task a meaningful name;
# - reuse the same logic;
# - make programs easier to read;
# - apply the same rule to many records.
#
# In the next module, we will use functions to help check and process CSV data.
