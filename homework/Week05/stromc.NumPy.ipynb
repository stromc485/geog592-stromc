# %% [markdown]
# ### CHARLOTTE STROM
# ### GEOG 592

# %% [markdown]
# 1. locations[0] → "Oak"
# 2. locations[4] → "Elm"
# 3. locations[1:4] → ["Pine", "Maple", "Cedar"]
# 4. "Maple" → locations[2]
# 5. points[2] → [180, 260]
# 6. points[2][1] → 260
#     points[2] selects the third point
#     [1] selects the second coordinate (y)
# 7. X-coordinate of the second point → points[1][0] → 140
# pandas indexing
#
# 8. df["ft"] → pandas Series
#
#
# 9. df[["name", "ft"]]
# 10. df.iloc[1] → Pine, 48, B
# 11. First three rows:
# df.iloc[0:3]
# 12. Rows where ft > 30:
#     df[df["ft"] > 30]
# 13. df.iloc[1:3] → rows 1 and 2: Pine and Maple
#
#
# 14. points.shape → (4, 2)
#         4 = 4 rows/points
#         2 = 2 columns/coordinates
# 15. points[0] → [100, 200]
# 16. points[0, 1] → 200
# 17. points[:, 0] → [100, 140, 180, 120]
#         (Note to self) : means all rows
#          (Note to self) 0 means first column
# 18. points[:, 1] → [200, 230, 260, 280]
# 19. Second and third rows:
#         points[1:3]
# 20. points[2][1] and points[2, 1] both return 260.
#         (The second is the more direct NumPy 2-D indexing syntax.)
#
# 21. points + shift →
# [[110, 220],
#  [150, 250],
#  [190, 280],
#  [130, 300]]
#
# 22. This is because NumPy will perform vectorized operations, which applies the addition to every element automatically without needing a Python for loop.
#
# 23. inside[:] →
# [False, True, False, True]
# 24. points[inside] →
# [[140, 230],
#  [120, 280]]
# 25. It approximates a spatial query (like a filter), to specifically select the points within a rectangular bounding box.
#
# np.where()
# 26.
# classes[:] →
# [0, 1, 0, 1]
#
# 27. np.where(condition, value_if_true, value_if_false):
# condition = what you're checking
# value_if_true = value assigned when the condition is true
# value_if_false = value assigned when the condition is false
#
# 28. a - b →
# [-40, -30]
#
# 29. It is vectorized arithmetic because NumPy SUBTRACTS the corresponding elements of the two arrays all at ONCE, rather than requiring a loop.
#
# 30. ft_array → NumPy ndarray
#
# 31. The pandas index and column label are removed when converted to a NumPy array. Just returns the values.
#
# 32. Big Picture: (everything after the arrow is my answer to the blank on the table)
# Python list	locations[2] -> Third item: "Maple"
# Nested Python list	points_list[2][1] ->	Second coordinate of the third point
# pandas DataFrame	df.iloc[2, 1] ->	Value in third row, second column: 31
# NumPy array	points[2, 1] ->	Value in third row, second column: 260
# NumPy array	points[:, 0] ->	All values in the first column: [100, 140, 180, 120]
#
# 33. The main idea of indexing is that it selects specific elements, rows, columns, or ranges based on their position.
#
# 34. A 2-D numpy array can efficiently select and perform calculations on entire rows, columns, or subsets of data using concise indexing and vectorized operations.
